# %% [markdown]
# # Capítulo 12. Programando en la red
#
# Alejandro E. Martínez Castro (amcastro@ugr.es)
#
# Tomado de C. Severance. "Python for Informatics"

# %% [markdown]
# ## Accediendo a datos de páginas web con *urllib*
#
# En primer lugar importaremos el módulo ´urlopen´ de la librería ´urllib.request´ para acceder a un fichero que está en la red. Pruebe abrir el navegador y visualícelo [AQUI](http://www.py4inf.com/code/romeo.txt).

# %%
from urllib.request import urlopen

fhand = urlopen('http://www.py4inf.com/code/romeo.txt')

for line in fhand: 
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %% [markdown]
# A continuación podemos hacer un programa que acceda a los datos del fichero *'romeo.txt'* y devuelva la frecuencia de cada palabra.

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
    
counts = dict()
for line in fhand:
    words = line.decode().split()
    for word in words:
        counts[word] = counts.get(word, 0) + 1
print(counts)
# Out:
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}

# %% [markdown]
# Lo que este bloque de código hace es:
# - Abre 'romeo.txt', y lo asigna a *fhand*.
# - Se genera un diccionario *counts*
# - Línea a línea en *fhand*, extrae una lista con las palabras. Esto se realiza primero decodificando, y luego separando en una lista.
# - Finalmente, para cada línea, se cuenta el número de veces que aparece

# %%
counts.get('But',0)
# Out:
# 1

# %% [markdown]
# ## Lectura de ficheros binarios con *urllib*
#
# En ocasiones es necesario capturar ficheros que no contienen texto, como ficheros de imágenes, audio, vídeo, etc. En estos casos es posible realizar la descarga directa de este material, que está en la web, a nuestro disco duro. Para esto podemos usar también *urllib*.
#
# Para esto, el primer paso será abrir el contenido remoto, y descargarlo, mediante *read()*

# %%
import urllib.request, urllib.parse, urllib.error
img = urllib.request.urlopen('http://data.pr4e.org/cover3.jpg').read()
fhand = open('cover3.jpg', 'wb')
fhand.write(img)
fhand.close()

# %% [markdown]
# Est programa lee todo el fichero de una vez, y lo almacena en la variable *img*. Posteriormente abre un fichero, le asigna el nombre 'cover3.jpg', y vuelca el contenido de *img* en el fichero. Podemos verificar con el explorador de archivos que este fichero se ha creado en la carpeta de este cuaderno, y que contiene una imagen de portada de un libro.
#
# Si el fichero fuese muy grande (audio, película, etc), esta operación no puede realizarse de una vez, por limitaciones de memoria. En tal caso se recurre a un *buffer*. Mediante esta técnica, la información se compacta en bloques (buffers), que se van almacenando en el disco poco a poco, a medida que van leyéndose.

# %%
import urllib.request, urllib.parse, urllib.error
img = urllib.request.urlopen('http://data.pr4e.org/cover3.jpg')
fhand = open('cover3.jpg', 'wb')
size = 0
while True:
  info = img.read(100000)
  if len(info) < 1: break
  size = size + len(info)
  fhand.write(info)

print(size, 'characters copied.')
fhand.close()
# Out:
# 230210 characters copied.

# %% [markdown]
# En este ejemplo, se leen únicamente 100000 caracteres en cada bloque. Posteriormente se van volcando de forma aditiva al fichero 'cover3.jpg'.

# %% [markdown]
# ## Análisis HTML y scraping de la web
#
# Uno de los usos habituales de *urllib* es para hacer **scraping de la web**. Esto no es otra cosa que escribir un programa que simule ser un navegador, capture datos de la web, y en vez de mostrarlos meramente en pantalla, realice otras tareas, como el análisis de esos datos. El propio uso de Google, por ejemplo, puede interpretarse como un scrapping de la web, ya que formalmente Google analiza los datos, enlaces a otras páginas, etc.

# %% [markdown]
# ## Análisis HTML usando expresiones regulares
#
# Una de las formas más sencillas de extraer datos de la web consiste en usar las expresiones regulares, para búsqueda y extracción de cadenas de texto que encajan dentro de un patrón predefinido.
#
# Consideremos el siguiente bloque de código html:
#
#     <h1>La primera página</h1>
#     <p>
#     Si lo desea, puede ver más en el siguiente link
#     <a href="http://www.dr-chuck.com/page2.htm">
#     segunda página</a>.
#     </p>
#
# En este caso, podemos construir una expresión regular para extraer los enlaces, como sigue:
#
#     href="http[s]?://.+?"
#
# Esta expresión regular busca en páginas que empiezan con "href=http://" o "href=https://", seguido de uno o más caracteres (.+?), seguido de una doble comilla. El signo de interrogación tras [s]? hace alusión a la búsqueda de http seguido de 0 o 1 vez el carácter 's'. Este tipo de búsqueda es *no ambiciosa* (no greedy), y trata de localizar siempre la mínima cadena de caracteres que cumple con el requisito de búsqueda.
#
# Para extraer la parte deseada, debemos añadir paréntesis a nuestra expresión regular.
#
# El siguiente bloque de código pone esto en contexto. Al ejecutarlo, podemos introducir, sin comillas, cualquier nombre completa de web. Por ejemplo:
#
#     http://www.ugr.es
#
# El código devuelve un listado de todos los links que enlaza esta página.

# %%
# Búsqueda de links en una URL
import urllib.request, urllib.parse, urllib.error
import re
import ssl

# Ignorar errores de certificado SSL 
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url).read()
links = re.findall(b'href="(http[s]?://.*?)"', html)
for link in links:
    print(link.decode())
# Out:
# Enter - http://www.ugr.es
# http://www.ugr.es/
# http://www.ugr.es/
# https://www.ugr.es/sites/default/files/ugr-marca-horizontal-color%403x.png
# https://www.facebook.com/universidadgranada/
# https://twitter.com/canalugr
# https://www.youtube.com/user/UGRmedios
# https://www.ugr.es/servicios/correo-electronico
# https://oficinavirtual.ugr.es/ai/
# https://www.facebook.com/universidadgranada/
# https://twitter.com/canalugr
# https://www.youtube.com/user/UGRmedios
# https://www.ugr.es/servicios/correo-electronico
# https://oficinavirtual.ugr.es/ai/
# https://sede.ugr.es
# https://oficinavirtual.ugr.es
# https://biblioteca.ugr.es
# https://prado.ugr.es
# https://directorio.ugr.es
# https://transparente.ugr.es
# https://calidad.ugr.es
# https://calidad.ugr.es/politica
# https://cartaservicios.ugr.es
# https://secretariageneral.ugr.es/bougr/
# https://archivo.ugr.es/
# https://consejosocial.ugr.es/
# https://defensor.ugr.es/
# https://secretariageneral.ugr.es/pages/convenios
# https://abierta.ugr.es
# https://csirc.ugr.es
# https://cic.ugr.es
# https://ceprud.ugr.es
# https://catedras.ugr.es
# https://ofiweb.ugr.es
# https://canal.ugr.es
# https://unidadigualdad.ugr.es
# https://www.universia.es/
# https://investigacion.ugr.es/pages/hrs4r
# https://www.arqus-alliance.eu/
# https://www.facebook.com/universidadgranada/
# https://twitter.com/canalugr
# https://www.youtube.com/user/UGRmedios
# https://www.ugr.es/servicios/correo-electronico
# https://oficinavirtual.ugr.es/ai/

# %% [markdown]
# Las expresiones regulares funcionan muy bien, siempre que el código HTML esté bien formateado. Pero esto, en la web, no es lo corriente. Existen muchas páginas con código "roto", etiquetas redundantes, etc. Es necesario por tanto recurrir a un analizador de código (que se denomina *parser*). El paquete BeautifulSoup ofrece un analizador avanzado. Veámoslo en la siguiente sección.

# %% [markdown]
# ## El paquete BeautifulSoup
#
# Aunque el código HTML se parezca al XML (eXtensive Markup Languaje), la mayor parte de las páginas escritas en HTML tienen fallos en su sintaxis, etiquetado, etc. Si se introduce cualquier página HTML en un analizador (parser) de código XML, indicará que falla debido a estructura defectuosa.
#
# Existen paquetes Python dedicados a extraer información estructurada de código HTML. Uno de ellos es BeautifulSoup.
#
# En general, usaremos la librería *urllib* para leer la página, y *BeautifulSoup* para para extraer los atributos *href* de las etiquetas.
#
# El siguiente bloque de código pide al usuario que escriba una página web (completa). Entonces, abre la página, lee el contenido, y pasa los datos a un objeto de BeautifulSoup. Tras esto, genera todas las etiquetas de anclaje (de tipo <a)  e imprime el atributo de *href* para cada etiqueta.

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignorar los errores del certificado SSL
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# Introducir una URL completa, sin comillas, e.g. http://www.ugr.es
url = input('Enter - ')
html = urllib.request.urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, 'html.parser')

# Recuperar todas las etiquetas de anclaje
tags = soup('a')
for tag in tags:
    print(tag.get('href', None))
# Out:
# Enter - http://www.ugr.es
# #main-content
# /
# /en
# https://www.facebook.com/universidadgranada/
# https://twitter.com/canalugr
# https://www.youtube.com/user/UGRmedios
# https://www.ugr.es/servicios/correo-electronico
# https://oficinavirtual.ugr.es/ai/
# /
# /
# /en
# https://www.facebook.com/universidadgranada/
# https://twitter.com/canalugr
# https://www.youtube.com/user/UGRmedios
# https://www.ugr.es/servicios/correo-electronico
# https://oficinavirtual.ugr.es/ai/
# /
# /en
#
# /universidad/organizacion/saludo-rectora
# /universidad/oficina-virtual
# /universidad/sede-electronica
# /historia/cronologia
# /universidad/normativa/basica
# /universidad/estudiar-en-la-ugr
# /universidad/noticias/portada
# /universidad/servicios
#
# /estudiantes/accesibilidad
# /estudiantes/acceso-a-la-universidad
# /estudiantes/que-estudiar
# /estudiantes/grados
# /estudiantes/master-doctorados
# /estudiantes/prado
# /estudiantes/correo-electronico
# /estudiantes/becas-y-ayudas
# /estudiantes/practicas
# /estudiantes/alojamiento/servicio-de-alojamiento
# /estudiantes/movilidad-e-intercambio/movilidad-internacional
#
# /personal/servicios/informacion-general
# /personal/correo-electronico
# /personal/directorio
# /personal/pas/informacion-general
# /personal/pdi/informacion-general
#
# /empresas/investigacion
# /empresas/transferencia
# /empresas/portal-de-facturas
# /empresas/contratacion
# /empresas/emprendimiento
# /servicios/fundacion-general-universidad-de-granada
# /empresas/practicas
#
# /visitantes/mecenazgo
# /visitantes/agenda-cultural
# /visitantes/alojamiento/granada
# /visitantes/empleo
# /visitantes/tienda-universitaria
# /universidad/servicios/educaugr
# /universidad/servicios/alumni
#
# /contacto/enviar-mensaje
# /contacto/como-llegar/datos-de-contacto-de-la-universidad-de-granada
# /personal/directorio
# None
# /destacado/oferta-academica-Grados-Masteres-y-Doctorados
# /universidad/noticias/ugr-primeras-espana-transparencia
# /universidad/noticias/ugr-estrena-este-viernes-opera-lelisir-damore
# /universidad/noticias/universidades-debaten-cultura-universitaria-patrimonio
# /universidad/noticias/metodo-inteligencia-artificial-conservacion-ballenas
# /universidad/noticias/angeles-lara-premio-menina-2019
# /universidad/noticias/aprender-divulgar-sus-investigaciones-medios-comunicacion
# /universidad/noticias/portada
# /servicios/correo-electronico
# https://sede.ugr.es
# https://oficinavirtual.ugr.es
# https://biblioteca.ugr.es
# https://prado.ugr.es
# https://directorio.ugr.es
# /empresas/investigacion
# /empresas/portal-de-facturas
# /universidad/normativa/estatutos
# https://transparente.ugr.es
# https://calidad.ugr.es
# /comunicaciones-oficiales/acuerdos-consejo-gobierno-25112019
# /comunicaciones-oficiales/convocatorias-erasmus-curso-20202021
# /comunicaciones-oficiales/eleccion-defensor-universitario
# /comunicaciones-oficiales/contribuye-desarrollo-sostenible-ugr
# /comunicaciones-oficiales/becas-ayudas-estudio-caracter-general-plan-propio-becas
# /comunicaciones-oficiales/cursos-del-centro-mediterraneo
# /comunicaciones-anteriores
# /visitantes/agenda-cultural/cineforum-observando-naturaleza-yaguarete-ultima-frontera
# /visitantes/agenda-cultural/cineforum-observando-naturaleza-yaguarete-ultima-frontera
# /visitantes/agenda-cultural/seminario-analisis-redes-sociales-una-introduccion-ciencias-sociales-un-estudio-caso
# /visitantes/agenda-cultural/seminario-analisis-redes-sociales-una-introduccion-ciencias-sociales-un-estudio-caso
# /visitantes/agenda-cultural/cineforum-ods-cine-sesion-5
# /visitantes/agenda-cultural/cineforum-ods-cine-sesion-5
# /visitantes/agenda-cultural/cineclub-universitario-ciclo-maestro-chaplin-etapa-mutual-programa-no-1-1916
# /visitantes/agenda-cultural/cineclub-universitario-ciclo-maestro-chaplin-etapa-mutual-programa-no-1-1916
# /visitantes/agenda-cultural/portada
# /destacado/universidad-de-granada-lider-investigacion
# /destacado/Informacion-para-nuevos-estudiantes
# /destacado/internacionalizacion
# /
# https://calidad.ugr.es/politica
# https://cartaservicios.ugr.es
# https://secretariageneral.ugr.es/bougr/
# https://archivo.ugr.es/
# /universidad/organizacion/entidades/inspeccion-servicios
# https://consejosocial.ugr.es/
# https://defensor.ugr.es/
# /perfil-del-contratante
# https://secretariageneral.ugr.es/pages/convenios
# https://abierta.ugr.es
# /universidad/servicios/sprl
# /universidad/organizacion/otros-centros/centro-de-iniciativas-de-cooperacion-al-desarrollo
# /universidad/servicios/cm
# /universidad/servicios/cpep
# /servicios/aula-permanente-de-formacion-abierta
# https://csirc.ugr.es
# https://cic.ugr.es
# https://ceprud.ugr.es
# https://catedras.ugr.es
# https://ofiweb.ugr.es
# /universidad/servicios/congresos
# https://canal.ugr.es
# https://unidadigualdad.ugr.es
# https://www.universia.es/
# https://investigacion.ugr.es/pages/hrs4r
# https://www.arqus-alliance.eu/
# /accesibilidad
# /condiciones-legales
# /rss-noticias
# /sitemap
# https://www.facebook.com/universidadgranada/
# https://twitter.com/canalugr
# https://www.youtube.com/user/UGRmedios
# https://www.ugr.es/servicios/correo-electronico
# https://oficinavirtual.ugr.es/ai/

# %% [markdown]
# Esta lista es algo más amplia que la que se obtuvo usando la expresión regular. Esto es así porque ahora podemos detectar enlaces que no incluyan los términos 'http'.
#
# Es posible usar BeutifulSoup para extraer varias partes de una etiqueta.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Ignorar el certificado SSL
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, "html.parser")

# Extraer todas las etiquetas de anclaje
tags = soup('a')
for tag in tags:
    # Mirar en partes de una etiqueta
    print('TAG:', tag)
    print('URL:', tag.get('href', None))
    print('Contents:', tag.contents[0])
    print('Attrs:', tag.attrs)
# Out:
# Enter - http://www.ugr.es
# TAG: <a class="visually-hidden focusable skip-link" href="#main-content">
#       Pasar al contenido principal
#     </a>
# URL: #main-content
# Contents:
#       Pasar al contenido principal
#
# Attrs: {'href': '#main-content', 'class': ['visually-hidden', 'focusable', 'skip-link']}
# TAG: <a class="is-active" href="/">Español</a>
# URL: /
# Contents: Español
# Attrs: {'class': ['is-active'], 'href': '/'}
# TAG: <a href="/en">English</a>
# URL: /en
# Contents: English
# Attrs: {'href': '/en'}
# TAG: <a class="facebook" href="https://www.facebook.com/universidadgranada/" target="_blank">facebook</a>
# URL: https://www.facebook.com/universidadgranada/
# Contents: facebook
# Attrs: {'href': 'https://www.facebook.com/universidadgranada/', 'class': ['facebook'], 'target': '_blank'}
# TAG: <a class="twitter" href="https://twitter.com/canalugr" target="_blank">twitter</a>
# URL: https://twitter.com/canalugr
# Contents: twitter
# Attrs: {'href': 'https://twitter.com/canalugr', 'class': ['twitter'], 'target': '_blank'}
# TAG: <a class="ugr_media" href="https://www.youtube.com/user/UGRmedios" target="_blank">ugr_media</a>
# URL: https://www.youtube.com/user/UGRmedios
# Contents: ugr_media
# Attrs: {'href': 'https://www.youtube.com/user/UGRmedios', 'class': ['ugr_media'], 'target': '_blank'}
# TAG: <a class="email" href="https://www.ugr.es/servicios/correo-electronico" target="_blank">email</a>
# URL: https://www.ugr.es/servicios/correo-electronico
# Contents: email
# Attrs: {'href': 'https://www.ugr.es/servicios/correo-electronico', 'class': ['email'], 'target': '_blank'}
# TAG: <a class="link_secretary" href="https://oficinavirtual.ugr.es/ai/" target="_blank">link_secretary</a>
# URL: https://oficinavirtual.ugr.es/ai/
# Contents: link_secretary
# Attrs: {'href': 'https://oficinavirtual.ugr.es/ai/', 'class': ['link_secretary'], 'target': '_blank'}
# TAG: <a class="site-logo" href="/" rel="home" title="Home">
# <img alt="Home" src="/sites/default/files/ugr-marca-horizontal-color%403x.png"/>
# </a>
# URL: /
# Contents:
#
# Attrs: {'href': '/', 'title': 'Home', 'rel': ['home'], 'class': ['site-logo']}
# TAG: <a class="is-active" href="/">Español</a>
# URL: /
# Contents: Español
# Attrs: {'class': ['is-active'], 'href': '/'}
# TAG: <a href="/en">English</a>
# URL: /en
# Contents: English
# Attrs: {'href': '/en'}
# TAG: <a class="facebook" href="https://www.facebook.com/universidadgranada/" target="_blank">facebook</a>
# URL: https://www.facebook.com/universidadgranada/
# Contents: facebook
# Attrs: {'href': 'https://www.facebook.com/universidadgranada/', 'class': ['facebook'], 'target': '_blank'}
# TAG: <a class="twitter" href="https://twitter.com/canalugr" target="_blank">twitter</a>
# URL: https://twitter.com/canalugr
# Contents: twitter
# Attrs: {'href': 'https://twitter.com/canalugr', 'class': ['twitter'], 'target': '_blank'}
# TAG: <a class="ugr_media" href="https://www.youtube.com/user/UGRmedios" target="_blank">ugr_media</a>
# URL: https://www.youtube.com/user/UGRmedios
# Contents: ugr_media
# Attrs: {'href': 'https://www.youtube.com/user/UGRmedios', 'class': ['ugr_media'], 'target': '_blank'}
# TAG: <a class="email" href="https://www.ugr.es/servicios/correo-electronico" target="_blank">email</a>
# URL: https://www.ugr.es/servicios/correo-electronico
# Contents: email
# Attrs: {'href': 'https://www.ugr.es/servicios/correo-electronico', 'class': ['email'], 'target': '_blank'}
# TAG: <a class="link_secretary" href="https://oficinavirtual.ugr.es/ai/" target="_blank">link_secretary</a>
# URL: https://oficinavirtual.ugr.es/ai/
# Contents: link_secretary
# Attrs: {'href': 'https://oficinavirtual.ugr.es/ai/', 'class': ['link_secretary'], 'target': '_blank'}
# TAG: <a class="is-active" href="/">Español</a>
# URL: /
# Contents: Español
# Attrs: {'class': ['is-active'], 'href': '/'}
# TAG: <a href="/en">English</a>
# URL: /en
# Contents: English
# Attrs: {'href': '/en'}
# TAG: <a class="is-active" data-drupal-link-system-path="&lt;front&gt;" href="" target="_self">Universidad</a>
# URL:
# Contents: Universidad
# Attrs: {'href': '', 'target': '_self', 'data-drupal-link-system-path': '<front>', 'class': ['is-active']}
# TAG: <a data-drupal-link-system-path="node/3" href="/universidad/organizacion/saludo-rectora" target="_self">Organización</a>
# URL: /universidad/organizacion/saludo-rectora
# Contents: Organización
# Attrs: {'href': '/universidad/organizacion/saludo-rectora', 'target': '_self', 'data-drupal-link-system-path': 'node/3'}
# TAG: <a data-drupal-link-system-path="node/15225" href="/universidad/oficina-virtual" target="_self">Oficina virtual</a>
# URL: /universidad/oficina-virtual
# Contents: Oficina virtual
# Attrs: {'href': '/universidad/oficina-virtual', 'target': '_self', 'data-drupal-link-system-path': 'node/15225'}
# TAG: <a data-drupal-link-system-path="node/229295" href="/universidad/sede-electronica" target="_self" title="Información sobre la Sede Electrónica">Sede electrónica</a>
# URL: /universidad/sede-electronica
# Contents: Sede electrónica
# Attrs: {'href': '/universidad/sede-electronica', 'target': '_self', 'title': 'Información sobre la Sede Electrónica', 'data-drupal-link-system-path': 'node/229295'}
# TAG: <a data-drupal-link-system-path="taxonomy/term/1" href="/historia/cronologia" target="_self">Historia</a>
# URL: /historia/cronologia
# Contents: Historia
# Attrs: {'href': '/historia/cronologia', 'target': '_self', 'data-drupal-link-system-path': 'taxonomy/term/1'}
# TAG: <a data-drupal-link-system-path="node/778709" href="/universidad/normativa/basica" target="_self">Normativa</a>
# URL: /universidad/normativa/basica
# Contents: Normativa
# Attrs: {'href': '/universidad/normativa/basica', 'target': '_self', 'data-drupal-link-system-path': 'node/778709'}
# TAG: <a data-drupal-link-system-path="node/6" href="/universidad/estudiar-en-la-ugr" target="_self">Estudiar en la UGR</a>
# URL: /universidad/estudiar-en-la-ugr
# Contents: Estudiar en la UGR
# Attrs: {'href': '/universidad/estudiar-en-la-ugr', 'target': '_self', 'data-drupal-link-system-path': 'node/6'}
# TAG: <a data-drupal-link-system-path="universidad/noticias/portada" href="/universidad/noticias/portada" target="_self">Noticias</a>
# URL: /universidad/noticias/portada
# Contents: Noticias
# Attrs: {'href': '/universidad/noticias/portada', 'target': '_self', 'data-drupal-link-system-path': 'universidad/noticias/portada'}
# TAG: <a data-drupal-link-system-path="node/229298" href="/universidad/servicios" target="_self" title="Servicios ofertados por la universidad de Granada">Servicios</a>
# URL: /universidad/servicios
# Contents: Servicios
# Attrs: {'href': '/universidad/servicios', 'target': '_self', 'title': 'Servicios ofertados por la universidad de Granada', 'data-drupal-link-system-path': 'node/229298'}
# TAG: <a class="is-active" data-drupal-link-system-path="&lt;front&gt;" href="" target="_self">Estudiantes</a>
# URL:
# Contents: Estudiantes
# Attrs: {'href': '', 'target': '_self', 'data-drupal-link-system-path': '<front>', 'class': ['is-active']}
# TAG: <a data-drupal-link-system-path="node/673400" href="/estudiantes/accesibilidad" target="_self">Accesibilidad</a>
# URL: /estudiantes/accesibilidad
# Contents: Accesibilidad
# Attrs: {'href': '/estudiantes/accesibilidad', 'target': '_self', 'data-drupal-link-system-path': 'node/673400'}
# TAG: <a data-drupal-link-system-path="node/15226" href="/estudiantes/acceso-a-la-universidad" target="_self">Acceso a la universidad</a>
# URL: /estudiantes/acceso-a-la-universidad
# Contents: Acceso a la universidad
# Attrs: {'href': '/estudiantes/acceso-a-la-universidad', 'target': '_self', 'data-drupal-link-system-path': 'node/15226'}
# TAG: <a data-drupal-link-system-path="node/20" href="/estudiantes/que-estudiar" target="_self">¿Qué estudiar?</a>
# URL: /estudiantes/que-estudiar
# Contents: ¿Qué estudiar?
# Attrs: {'href': '/estudiantes/que-estudiar', 'target': '_self', 'data-drupal-link-system-path': 'node/20'}
# TAG: <a data-drupal-link-system-path="node/11015560" href="/estudiantes/grados" target="_self">Grados</a>
# URL: /estudiantes/grados
# Contents: Grados
# Attrs: {'href': '/estudiantes/grados', 'target': '_self', 'data-drupal-link-system-path': 'node/11015560'}
# TAG: <a data-drupal-link-system-path="node/777209" href="/estudiantes/master-doctorados" target="_self">Máster y doctorados</a>
# URL: /estudiantes/master-doctorados
# Contents: Máster y doctorados
# Attrs: {'href': '/estudiantes/master-doctorados', 'target': '_self', 'data-drupal-link-system-path': 'node/777209'}
# TAG: <a data-drupal-link-system-path="node/15227" href="/estudiantes/prado" target="_self">Plataforma docente</a>
# URL: /estudiantes/prado
# Contents: Plataforma docente
# Attrs: {'href': '/estudiantes/prado', 'target': '_self', 'data-drupal-link-system-path': 'node/15227'}
# TAG: <a data-drupal-link-system-path="node/15228" href="/estudiantes/correo-electronico" target="_self">Correo Estudiantes</a>
# URL: /estudiantes/correo-electronico
# Contents: Correo Estudiantes
# Attrs: {'href': '/estudiantes/correo-electronico', 'target': '_self', 'data-drupal-link-system-path': 'node/15228'}
# TAG: <a data-drupal-link-system-path="node/8057293" href="/estudiantes/becas-y-ayudas" target="_self">Becas y Ayudas</a>
# URL: /estudiantes/becas-y-ayudas
# Contents: Becas y Ayudas
# Attrs: {'href': '/estudiantes/becas-y-ayudas', 'target': '_self', 'data-drupal-link-system-path': 'node/8057293'}
# TAG: <a data-drupal-link-system-path="node/229367" href="/estudiantes/practicas" target="_self">Prácticas</a>
# URL: /estudiantes/practicas
# Contents: Prácticas
# Attrs: {'href': '/estudiantes/practicas', 'target': '_self', 'data-drupal-link-system-path': 'node/229367'}
# TAG: <a data-drupal-link-system-path="node/26" href="/estudiantes/alojamiento/servicio-de-alojamiento" target="_self">Alojamiento Estudiantes</a>
# URL: /estudiantes/alojamiento/servicio-de-alojamiento
# Contents: Alojamiento Estudiantes
# Attrs: {'href': '/estudiantes/alojamiento/servicio-de-alojamiento', 'target': '_self', 'data-drupal-link-system-path': 'node/26'}
# TAG: <a data-drupal-link-system-path="node/15221" href="/estudiantes/movilidad-e-intercambio/movilidad-internacional" target="_self">Movilidad e intercambio</a>
# URL: /estudiantes/movilidad-e-intercambio/movilidad-internacional
# Contents: Movilidad e intercambio
# Attrs: {'href': '/estudiantes/movilidad-e-intercambio/movilidad-internacional', 'target': '_self', 'data-drupal-link-system-path': 'node/15221'}
# TAG: <a class="is-active" data-drupal-link-system-path="&lt;front&gt;" href="" target="_self">Personal</a>
# URL:
# Contents: Personal
# Attrs: {'href': '', 'target': '_self', 'data-drupal-link-system-path': '<front>', 'class': ['is-active']}
# TAG: <a data-drupal-link-system-path="node/777208" href="/personal/servicios/informacion-general" target="_self">Servicios</a>
# URL: /personal/servicios/informacion-general
# Contents: Servicios
# Attrs: {'href': '/personal/servicios/informacion-general', 'target': '_self', 'data-drupal-link-system-path': 'node/777208'}
# TAG: <a data-drupal-link-system-path="node/229296" href="/personal/correo-electronico" target="_self" title="Correo electrónico para el personal de la Universidad de Granada">Correo PDI-PAS</a>
# URL: /personal/correo-electronico
# Contents: Correo PDI-PAS
# Attrs: {'href': '/personal/correo-electronico', 'target': '_self', 'title': 'Correo electrónico para el personal de la Universidad de Granada', 'data-drupal-link-system-path': 'node/229296'}
# TAG: <a data-drupal-link-system-path="node/1690062" href="/personal/directorio" target="_self">Directorio</a>
# URL: /personal/directorio
# Contents: Directorio
# Attrs: {'href': '/personal/directorio', 'target': '_self', 'data-drupal-link-system-path': 'node/1690062'}
# TAG: <a data-drupal-link-system-path="node/778087" href="/personal/pas/informacion-general" target="_self">PAS</a>
# URL: /personal/pas/informacion-general
# Contents: PAS
# Attrs: {'href': '/personal/pas/informacion-general', 'target': '_self', 'data-drupal-link-system-path': 'node/778087'}
# TAG: <a data-drupal-link-system-path="node/778088" href="/personal/pdi/informacion-general" target="_self">PDI</a>
# URL: /personal/pdi/informacion-general
# Contents: PDI
# Attrs: {'href': '/personal/pdi/informacion-general', 'target': '_self', 'data-drupal-link-system-path': 'node/778088'}
# TAG: <a class="is-active" data-drupal-link-system-path="&lt;front&gt;" href="" target="_self">Empresas</a>
# URL:
# Contents: Empresas
# Attrs: {'href': '', 'target': '_self', 'data-drupal-link-system-path': '<front>', 'class': ['is-active']}
# TAG: <a data-drupal-link-system-path="node/229212" href="/empresas/investigacion" target="_self">Investigación</a>
# URL: /empresas/investigacion
# Contents: Investigación
# Attrs: {'href': '/empresas/investigacion', 'target': '_self', 'data-drupal-link-system-path': 'node/229212'}
# TAG: <a data-drupal-link-system-path="node/229213" href="/empresas/transferencia" target="_self">Transferencia</a>
# URL: /empresas/transferencia
# Contents: Transferencia
# Attrs: {'href': '/empresas/transferencia', 'target': '_self', 'data-drupal-link-system-path': 'node/229213'}
# TAG: <a data-drupal-link-system-path="node/229214" href="/empresas/portal-de-facturas" target="_self">Portal de facturas</a>
# URL: /empresas/portal-de-facturas
# Contents: Portal de facturas
# Attrs: {'href': '/empresas/portal-de-facturas', 'target': '_self', 'data-drupal-link-system-path': 'node/229214'}
# TAG: <a data-drupal-link-system-path="node/229215" href="/empresas/contratacion" target="_self">Contratación</a>
# URL: /empresas/contratacion
# Contents: Contratación
# Attrs: {'href': '/empresas/contratacion', 'target': '_self', 'data-drupal-link-system-path': 'node/229215'}
# TAG: <a data-drupal-link-system-path="node/778259" href="/empresas/emprendimiento" target="_self">Emprendimiento</a>
# URL: /empresas/emprendimiento
# Contents: Emprendimiento
# Attrs: {'href': '/empresas/emprendimiento', 'target': '_self', 'data-drupal-link-system-path': 'node/778259'}
# TAG: <a data-drupal-link-system-path="node/229286" href="/servicios/fundacion-general-universidad-de-granada" target="_self">Fundación General UGR</a>
# URL: /servicios/fundacion-general-universidad-de-granada
# Contents: Fundación General UGR
# Attrs: {'href': '/servicios/fundacion-general-universidad-de-granada', 'target': '_self', 'data-drupal-link-system-path': 'node/229286'}
# TAG: <a data-drupal-link-system-path="node/7821373" href="/empresas/practicas" target="_self">Prácticas</a>
# URL: /empresas/practicas
# Contents: Prácticas
# Attrs: {'href': '/empresas/practicas', 'target': '_self', 'data-drupal-link-system-path': 'node/7821373'}
# TAG: <a class="is-active" data-drupal-link-system-path="&lt;front&gt;" href="" target="_self">Visitantes</a>
# URL:
# Contents: Visitantes
# Attrs: {'href': '', 'target': '_self', 'data-drupal-link-system-path': '<front>', 'class': ['is-active']}
# TAG: <a data-drupal-link-system-path="node/229361" href="/visitantes/mecenazgo" target="_self">Mecenazgo</a>
# URL: /visitantes/mecenazgo
# Contents: Mecenazgo
# Attrs: {'href': '/visitantes/mecenazgo', 'target': '_self', 'data-drupal-link-system-path': 'node/229361'}
# TAG: <a data-drupal-link-system-path="node/777294" href="/visitantes/agenda-cultural" target="_self">Agenda cultural</a>
# URL: /visitantes/agenda-cultural
# Contents: Agenda cultural
# Attrs: {'href': '/visitantes/agenda-cultural', 'target': '_self', 'data-drupal-link-system-path': 'node/777294'}
# TAG: <a data-drupal-link-system-path="node/229216" href="/visitantes/alojamiento/granada" target="_self">Alojamiento</a>
# URL: /visitantes/alojamiento/granada
# Contents: Alojamiento
# Attrs: {'href': '/visitantes/alojamiento/granada', 'target': '_self', 'data-drupal-link-system-path': 'node/229216'}
# TAG: <a data-drupal-link-system-path="node/229344" href="/visitantes/empleo" target="_self">Empleo</a>
# URL: /visitantes/empleo
# Contents: Empleo
# Attrs: {'href': '/visitantes/empleo', 'target': '_self', 'data-drupal-link-system-path': 'node/229344'}
# TAG: <a data-drupal-link-system-path="node/229461" href="/visitantes/tienda-universitaria" target="_self">Tienda universitaria</a>
# URL: /visitantes/tienda-universitaria
# Contents: Tienda universitaria
# Attrs: {'href': '/visitantes/tienda-universitaria', 'target': '_self', 'data-drupal-link-system-path': 'node/229461'}
# TAG: <a data-drupal-link-system-path="node/2324957" href="/universidad/servicios/educaugr" target="_self">Recursos Educativos</a>
# URL: /universidad/servicios/educaugr
# Contents: Recursos Educativos
# Attrs: {'href': '/universidad/servicios/educaugr', 'target': '_self', 'data-drupal-link-system-path': 'node/2324957'}
# TAG: <a data-drupal-link-system-path="node/2674519" href="/universidad/servicios/alumni" target="_self">Alumni</a>
# URL: /universidad/servicios/alumni
# Contents: Alumni
# Attrs: {'href': '/universidad/servicios/alumni', 'target': '_self', 'data-drupal-link-system-path': 'node/2674519'}
# TAG: <a class="is-active" data-drupal-link-system-path="&lt;front&gt;" href="" target="_self">Contacto</a>
# URL:
# Contents: Contacto
# Attrs: {'href': '', 'target': '_self', 'data-drupal-link-system-path': '<front>', 'class': ['is-active']}
# TAG: <a data-drupal-link-system-path="node/229207" href="/contacto/enviar-mensaje" target="_self">Enviar mensaje</a>
# URL: /contacto/enviar-mensaje
# Contents: Enviar mensaje
# Attrs: {'href': '/contacto/enviar-mensaje', 'target': '_self', 'data-drupal-link-system-path': 'node/229207'}
# TAG: <a data-drupal-link-system-path="node/24" href="/contacto/como-llegar/datos-de-contacto-de-la-universidad-de-granada" target="_self">¿Dónde estamos?</a>
# URL: /contacto/como-llegar/datos-de-contacto-de-la-universidad-de-granada
# Contents: ¿Dónde estamos?
# Attrs: {'href': '/contacto/como-llegar/datos-de-contacto-de-la-universidad-de-granada', 'target': '_self', 'data-drupal-link-system-path': 'node/24'}
# TAG: <a data-drupal-link-system-path="node/1690062" href="/personal/directorio" target="_self">Buscar personas/entidades</a>
# URL: /personal/directorio
# Contents: Buscar personas/entidades
# Attrs: {'href': '/personal/directorio', 'target': '_self', 'data-drupal-link-system-path': 'node/1690062'}
# TAG: <a id="main-content" tabindex="-1"></a>
# URL: None
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-90dc5feaa0d4> in <module>
#      18     print('TAG:', tag)
#      19     print('URL:', tag.get('href', None))
# ---> 20     print('Contents:', tag.contents[0])
#      21     print('Attrs:', tag.attrs)
#
# IndexError: list index out of range

# %% [markdown]
# El analizador html.parser es el standard incluido en Python 3. Hay otros analizadores. Ver en:
#
# http://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser
